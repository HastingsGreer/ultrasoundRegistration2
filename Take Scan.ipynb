# %%
from PIL import ImageGrab
import numpy as np
import matplotlib.pyplot as plt

# %%
import hackymouse
import time
bb = []
def setBB():
    print("move mouse to upper left hand corner")
    time.sleep(3)
    x, y = hackymouse.getPos()
    bb[:] = [x, y, x + 768, y + 768]
setBB()
# Out:
# move mouse to upper left hand corner

# %%
def takeVideo(n):
    times = []
    images = []
    for _ in range(n):
        times.append(time.time())
        images.append(ImageGrab.grab(bb))
    return np.array(times), np.array([np.array(u) for u in images])

def takeShot():
    return np.sum(np.array(ImageGrab.grab(bb), dtype=np.float64), 2)
#out2 = takeVideo(400)

# %%
v1 = takeVideo(400)
v2 = takeVideo(400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-848cca329473> in <module>()
# ----> 1 v1 = takeVideo(400)
#       2 v2 = takeVideo(400)
#
# <ipython-input-3-2bccaf6eb7fe> in takeVideo(n)
#       3     images = []
#       4     for _ in range(n):
# ----> 5         times.append(time.time())
#       6         images.append(ImageGrab.grab(bb))
#       7     return np.array(times), np.array([np.array(u) for u in images])
#
# NameError: name 'time' is not defined

# %%
#v7 = takeVideo(400)
import pickle

# %%
orientations = pickle.load(open("C:/d/ultrasoundHacks/website/1499721465.4148672", "rb"))

# %%
plt.imshow(v5[1][200])
plt.show()

# %%
pickle.dump([v1, v2, v3, v4, v5, v6, orientations], open("July 10 Data.pickle", "wb"))
